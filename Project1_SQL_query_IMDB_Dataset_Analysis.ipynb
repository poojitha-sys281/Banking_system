# %% [markdown]
# <a href="https://colab.research.google.com/github/poojitha-sys281/Banking_system/blob/main/Project1_SQL_query_IMDB_Dataset_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("rounakbanik/the-movies-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 228M/228M [00:08<00:00, 28.9MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/rounakbanik/the-movies-dataset/versions/7

# %% [markdown]
# # Importing the libaries

# %%
import numpy as np# mathematical operations
import pandas as pd# data manipulation tool
import matplotlib as plt# data visualization tool
import seaborn as sns# data visualization tool
import sqlite3# serverless database

# %% [markdown]
# #Hints and tips
# 1. connect your database (or create a connection) -> sqlite3.connect(database)
#
# 2. use the curser function -> database variable.cursor ()

# %% [markdown]
# # Workflow
# 1. You need to establish a connection to the SQLite database by creating a connecting object
# 2. we have to create cursor object using the cursor() method
#
# 3. now we are ready to execute the query-> cursor_object.execute('query')
# 4. To fetch the data,then use fetchchall() method of the cursor

# %% [markdown]
# # Establishing the connection with the database

# %%
data= pd.read_csv('https://people.sc.fsu.edu/~jburkardt/data/csv/hw_200.csv')

# %%
conn=sqlite3.connect('database1.sqlite')
cur=conn.cursor()

# %%
data= pd.read_csv('https://people.sc.fsu.edu/~jburkardt/data/csv/hw_200.csv')

# %%
conn=sqlite3.connect('database1.sqlite')
cur=conn.cursor()

# %% [markdown]
# #THE REAL PROJECT

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget https://raw.githubusercontent.com/peetck/IMDB-Top1000-Movies/master/IMDB-Movie-Data.csv \
    -O /content/drive/MyDrive/imdb_top_1000.csv
# Out:
# --2025-08-12 12:23:32--  https://raw.githubusercontent.com/peetck/IMDB-Top1000-Movies/master/IMDB-Movie-Data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 309028 (302K) [text/plain]
# Saving to: ‘/content/drive/MyDrive/imdb_top_1000.csv’
#
# /content/drive/MyDr 100%[===================>] 301.79K  --.-KB/s    in 0.04s
#
# 2025-08-12 12:23:33 (6.79 MB/s) - ‘/content/drive/MyDrive/imdb_top_1000.csv’ saved [309028/309028]

# %%
import numpy as np# mathematical operations
import pandas as pd# data manipulation tool
import matplotlib as plt# data visualization tool
import seaborn as sns# data visualization tool
import sqlite3# serverless database

# %%
conn=sqlite3.connect('database1.sqlite')
cur=conn.cursor()

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/imdb_top_1000.csv')
print(df.head())
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.to_sql('new_data', conn, if_exists='replace', index=False)
# Out:
# 1000

# %%
cur.execute('SELECT * FROM new_data')

# %%
table=cur.fetchall()

# %%
df=pd.DataFrame(table,columns=[
    'S.No',
    'Title',
    'Genre',
    'Description',
    'Director',
    'Actors',
    'Year',
    'Runtime (Minutes)',
    'IMDB Rating',
    'Votes',
    'Revenue (Millions)',
    'Metascore'
]
)

# %%
df
# Out:
#      S.No                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
cur.execute('select "Title" from new_data')

# %%
data1=cur.fetchall()

# %%
df1=pd.DataFrame(data1,columns=['Title'])

# %%
df1
# Out:
#                        Title
# 0    Guardians of the Galaxy
# 1                 Prometheus
# 2                      Split
# 3                       Sing
# 4              Suicide Squad
# ..                       ...
# 995     Secret in Their Eyes
# 996          Hostel: Part II
# 997   Step Up 2: The Streets
# 998             Search Party
# 999               Nine Lives
#
# [1000 rows x 1 columns]

# %%
number=len(df1)
print('These many movies are present in the table:',number)
# Out:
# These many movies are present in the table: 1000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Title   1000 non-null   object
# dtypes: object(1)
# memory usage: 7.9+ KB

# %%
cur.execute('select count(Title) from new_data')

# %%
count=cur.fetchall()

# %%
print(count[0])
# Out:
# (1000,)

# %%
cur.execute("select * from new_data where Director in ('David Ayer','Justin Lin')")

# %%
dic=cur.fetchall()

# %%
df=pd.DataFrame(table,columns=[
    'S.No',
    'Title',
    'Genre',
    'Description',
    'Director',
    'Actors',
    'Year',
    'Runtime (Minutes)',
    'IMDB Rating',
    'Votes',
    'Revenue (Millions)',
    'Metascore'
]
)

# %%
df
# Out:
#      S.No                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# # Print the director names that starts with 'Justin'

# %%
cur.execute("select * from new_data where Director LIKE 'Justin%'")

# %%
directors=cur.fetchall()
df=pd.DataFrame(directors)

# %%
df
# Out:
#      0                                      1                        2   \
# 0    30                       Assassin's Creed   Action,Adventure,Drama
# 1    49                       Star Trek Beyond  Action,Adventure,Sci-Fi
# 2   135                              Furious 6    Action,Crime,Thriller
# 3   263                      Dear White People             Comedy,Drama
# 4   309  The Fast and the Furious: Tokyo Drift    Action,Crime,Thriller
# 5   320                              Fast Five    Action,Crime,Thriller
# 6   341                         Fast & Furious    Action,Crime,Thriller
# 7   480                                Macbeth                Drama,War
# 8   948                             King Cobra              Crime,Drama
# 9   950                                  Kicks                Adventure
# 10  963                  The Other Boleyn Girl  Biography,Drama,History
#
#                                                    3                4   \
# ...

# %%
print(directors)
# Out:
# [(30, "Assassin's Creed", 'Action,Adventure,Drama', 'When Callum Lynch explores the memories of his ancestor Aguilar and gains the skills of a Master Assassin, he discovers he is a descendant of the secret Assassins society.', 'Justin Kurzel', 'Michael Fassbender, Marion Cotillard, Jeremy Irons,Brendan Gleeson', 2016, 115, 5.9, 112813, 54.65, 36), (49, 'Star Trek Beyond', 'Action,Adventure,Sci-Fi', 'The USS Enterprise crew explores the furthest reaches of uncharted space, where they encounter a new ruthless enemy who puts them and everything the Federation stands for to the test.', 'Justin Lin', 'Chris Pine, Zachary Quinto, Karl Urban, Zoe Saldana', 2016, 122, 7.1, 164567, 158.8, 68), (135, 'Furious 6', 'Action,Crime,Thriller', 'Hobbs has Dominic and Brian reassemble their crew to take down a team of mercenaries: Dominic unexpectedly gets convoluted also facing his presumed deceased girlfriend, Letty.', 'Justin Lin', 'Vin Diesel, Paul Walker, Dwayne Johnson, Michelle Rodriguez', 2013
# ...

# %% [markdown]
# # Print 3 most popular movies

# %%
cur.execute("SELECT Title FROM new_data ORDER BY 'IMDB Rating' desc LIMIT 3 ")

# %%
movies
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-878749064.py in <cell line: 0>()
# ----> 1 movies
#
# NameError: name 'movies' is not defined

# %%
movies=cur.fetchall()
print(f'The movies are {movies[0][0]},{movies[1][0]} and {movies[2][0]}')
# Out:
# The movies are Guardians of the Galaxy,Prometheus and Split

# %%
df11=pd.DataFrame(movies)

# %%
df11
# Out:
#                          0
# 0  Guardians of the Galaxy
# 1               Prometheus
# 2                    Split

# %% [markdown]
# #Print three most bankable movies

# %%
cur.execute('SELECT Title, "Revenue (Millions)"	FROM new_data ORDER BY "Revenue (Millions)" desc LIMIT 3')

# %%
movie=cur.fetchall()

# %%
movie
# Out:
# [('Star Wars: Episode VII - The Force Awakens', 936.63),
#  ('Avatar', 760.51),
#  ('Jurassic World', 652.18)]

# %%
print(f'The movies are\n {movie[0][0]},\n{movie[1][0]} \t and\n {movie[2][0]} \n and their budget is {movie[0][1]},{movie[1][1]} and {movie[2][1]}')
# Out:
# The movies are
#  Star Wars: Episode VII - The Force Awakens,
# Avatar 	 and
#  Jurassic World
#  and their budget is 936.63,760.51 and 652.18

# %%
df
# Out:
#      S.No                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# #print the movie title where that got high imdb rating and released since 2014

# %%
cur.execute('select Title from new_data where Year>2014  ORDER BY "IMDB Rating"  desc LIMIT 1 ')

# %%
awarded=cur.fetchall()
awarded
# Out:
# [('Split',)]

# %%
print(f'The movie with the highest imdb rating is {awarded[0][0]}')
# Out:
# The movie with the highest imdb rating is Split

# %% [markdown]
# #print the name of the director who have made highest movies of all directors

# %%
cur.execute('SELECT director FROM new_data GROUP BY director ORDER BY COUNT(*) DESC LIMIT 1')

# %%
curren=cur.fetchall()

# %%
print(curren)
# Out:
# [('Ridley Scott',)]

# %%
cur.execute("select Title from new_data where Director LIKE 'Ridley Scott'")

# %%
res=cur.fetchall()

# %%
res
# Out:
# [('Prometheus',),
#  ('The Martian',),
#  ('Robin Hood',),
#  ('American Gangster',),
#  ('Exodus: Gods and Kings',),
#  ('The Counselor',),
#  ('A Good Year',),
#  ('Body of Lies',)]

# %% [markdown]
# #print the bankable director name

# %%
cur.execute('''
    SELECT "Director", SUM("Revenue (Millions)") AS total_revenue
    FROM new_data
    GROUP BY "Director"
    ORDER BY total_revenue DESC
    LIMIT 1
''')

# %%
cur.fetchall()
# Out:
# [('J.J. Abrams', 1683.4499999999998)]

# %%
cur.execute('SELECT Title FROM new_data ORDER BY "Revenue (Millions)" DESC LIMIT 10')

# %%
moviesare=cur.fetchall()

# %%
moviesare
# Out:
# [('Star Wars: Episode VII - The Force Awakens',),
#  ('Avatar',),
#  ('Jurassic World',),
#  ('The Avengers',),
#  ('The Dark Knight',),
#  ('Rogue One',),
#  ('Finding Dory',),
#  ('Avengers: Age of Ultron',),
#  ('The Dark Knight Rises',),
#  ('The Hunger Games: Catching Fire',)]

# %%
df1=pd.DataFrame(moviesare)

# %%
df1
# Out:
#                                             0
# 0  Star Wars: Episode VII - The Force Awakens
# 1                                      Avatar
# 2                              Jurassic World
# 3                                The Avengers
# 4                             The Dark Knight
# 5                                   Rogue One
# 6                                Finding Dory
# 7                     Avengers: Age of Ultron
# 8                       The Dark Knight Rises
# 9             The Hunger Games: Catching Fire

# %% [markdown]
# #Revenue Analysis :--> tell the top 10 highest Revenue making movies

# %%
cur.execute("SELECT * FROM new_data ORDER BY 'Revenue (Millions)' DESC LIMIT 10")

# %%
df2=pd.DataFrame(cur.fetchall(),columns=[
    'S.No',
    'Title',
    'Genre',
    'Description',
    'Director',
    'Actors',
    'Year',
    'Runtime (Minutes)',
    'IMDB Rating',
    'Votes',
    'Revenue (Millions)',
    'Metascore'
])

# %%
df2
# Out:
#    S.No                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %% [markdown]
# # MetaScore Analysis :-->Top10 movies with highest metascore

# %%
cur.execute('SELECT * FROM new_data ORDER BY "Metascore" DESC LIMIT 10')

# %%
df3=pd.DataFrame(cur.fetchall(),columns=[
    'S.No',
    'Title',
    'Genre',
    'Description',
    'Director',
    'Actors',
    'Year',
    'Runtime (Minutes)',
    'IMDB Rating',
    'Votes',
    'Revenue (Millions)',
    'Metascore'
])

# %%
df3
# Out:
#    S.No                  Title                    Genre  \
# 0   657                Boyhood                    Drama
# 1    42              Moonlight                    Drama
# 2   231        Pan's Labyrinth        Drama,Fantasy,War
# 3    22  Manchester by the Sea                    Drama
# 4   112       12 Years a Slave  Biography,Drama,History
# 5   490            Ratatouille  Animation,Comedy,Family
# 6   510                Gravity    Drama,Sci-Fi,Thriller
# 7   325     The Social Network          Biography,Drama
# 8   407       Zero Dark Thirty   Drama,History,Thriller
# 9   502                  Carol            Drama,Romance
#
#                                          Description            Director  \
# 0  The life of Mason, from early childhood to his...   Richard Linklater
# 1  A chronicle of the childhood, adolescence and ...       Barry Jenkins
# 2  In the falangist Spain of 1944, the bookish yo...  Guillermo del Toro
# ...

# %% [markdown]
# #Print the Details of the movies where the movies with most votes should be at the top

# %%
cur.execute('SELECT * FROM new_data ORDER BY votes DESC LIMIT 10')

# %%
df4=pd.DataFrame(cur.fetchall(),columns=[
    'S.No',
    'Title',
    'Genre',
    'Description',
    'Director',
    'Actors',
    'Year',
    'Runtime (Minutes)',
    'IMDB Rating',
    'Votes',
    'Revenue (Millions)',
    'Metascore'
])

# %%
df4.columns
# Out:
# Index(['S.No', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'IMDB Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df4
# Out:
#    S.No                  Title                     Genre  \
# 0    55        The Dark Knight        Action,Crime,Drama
# 1    81              Inception   Action,Adventure,Sci-Fi
# 2   125  The Dark Knight Rises           Action,Thriller
# 3    37           Interstellar    Adventure,Drama,Sci-Fi
# 4    77           The Avengers             Action,Sci-Fi
# 5   145       Django Unchained             Drama,Western
# 6    78   Inglourious Basterds       Adventure,Drama,War
# 7   100           The Departed      Crime,Drama,Thriller
# 8    88                 Avatar  Action,Adventure,Fantasy
# 9    65           The Prestige      Drama,Mystery,Sci-Fi
#
#                                          Description           Director  \
# 0  When the menace known as the Joker wreaks havo...  Christopher Nolan
# 1  A thief, who steals corporate secrets through ...  Christopher Nolan
# 2  Eight years after the Joker's reign of anarchy...  Christopher Nolan
# ...

# %% [markdown]
# #Print the Director name ,number of movies,total revenue

# %%
cur.execute('''SELECT "Director",COUNT(*) AS movie_count,SUM("Revenue (Millions)")as total_revenue FROM new_data GROUP BY "Director" ''')

# %%
df5=pd.DataFrame(cur.fetchall(),columns=[
    'Director',
    'Count',
    'Revenue'
])

# %%
df5
# Out:
#                 Director  Count  Revenue
# 0             Aamir Khan      1     1.20
# 1    Abdellatif Kechiche      1     2.20
# 2              Adam Leon      1     0.00
# 3             Adam McKay      4   438.14
# 4          Adam Shankman      2   157.33
# ..                   ...    ...      ...
# 639         Xavier Dolan      2     3.49
# 640          Yimou Zhang      1    45.13
# 641     Yorgos Lanthimos      2     8.81
# 642          Zack Snyder      5   975.74
# 643        Zackary Adler      1     6.53
#
# [644 rows x 3 columns]

# %% [markdown]
# #

# %%
cur.execute('''SELECT "Director",COUNT(*) AS movie_count,SUM("Revenue (Millions)")as total_revenue FROM new_data GROUP BY "Director" ORDER BY total_revenue DESC  ''')

# %%
df6=pd.DataFrame(cur.fetchall(),columns=[
    'Director',
    'Count',
    'Revenue'
])

# %%
df6
# Out:
#               Director  Count  Revenue
# 0          J.J. Abrams      5  1683.45
# 1          David Yates      6  1630.51
# 2    Christopher Nolan      5  1515.09
# 3          Michael Bay      6  1421.32
# 4     Francis Lawrence      4  1299.81
# ..                 ...    ...      ...
# 639    Alex Ranarivelo      1     0.00
# 640       Akan Satayev      1     0.00
# 641      Aisling Walsh      1     0.00
# 642      Afonso Poyart      1     0.00
# 643          Adam Leon      1     0.00
#
# [644 rows x 3 columns]

# %%
#extra
cur.execute('''SELECT "Director","Revenue (Millions)"  FROM new_data WHERE "Revenue (Millions)" is 0 ''')

# %%
cur.fetchall()
# Out:
# [('Sean Foley', 0.0),
#  ('Ben Young', 0.0),
#  ('Dominique Abel', 0.0),
#  ('Patrick Read Johnson', 0.0),
#  ('Shawn Burkett', 0.0),
#  ('Scott Hicks', 0.0),
#  ('Sean Penn', 0.0),
#  ('André Øvredal', 0.0),
#  ('Terry George', 0.0),
#  ('Oriol Paulo', 0.0),
#  ('Katie Holmes', 0.0),
#  ('Ana Lily Amirpour', 0.0),
#  ('Todor Chapkanov', 0.0),
#  ('Martin Koolhoven', 0.0),
#  ('David Lynch', 0.0),
#  ('Fabio Guaglione', 0.0),
#  ('Jackson Stewart', 0.0),
#  ('Mateo Gil', 0.0),
#  ('Gaspar Noé', 0.0),
#  ('April Mullen', 0.0),
#  ('Akan Satayev', 0.0),
#  ('Colm McCarthy', 0.0),
#  ('Spike Lee', 0.0),
#  ('Liam Gavin', 0.0),
#  ('Steven Shainberg', 0.0),
#  ('Andy Goddard', 0.0),
#  ('Jeffrey G. Hunt', 0.0),
#  ('Eric Summer', 0.0),
#  ('Quentin Tarantino', 0.0),
#  ('Jalil Lespert', 0.0),
#  ('David Leveaux', 0.0),
#  ('Gary Michael Schultz', 0.0),
#  ('Dan Berk', 0.0),
#  ('Mike Flanagan', 0.0),
#  ('Alexi Pappas', 0.0),
#  ('William Oldroyd', 0.0),
#  ('Hugo Gélin', 0.0),
# ...

# %%
cur.execute('''SELECT "Title" ,"Year","Revenue (Millions)" ,"Votes","Rating" FROM new_data WHERE "Director" = 'Francis Lawrence' ORDER BY "Rating" DESC''')

# %%
df7=pd.DataFrame(cur.fetchall(),columns=[
    'Title',
    'Date',
    'Revenue',
    'Votes',
    'Rating'
])

# %%
df7
# Out:
#                                    Title  Date  Revenue   Votes  Rating
# 0        The Hunger Games: Catching Fire  2013   424.65  525646     7.6
# 1                            I Am Legend  2007   256.39  565721     7.2
# 2  The Hunger Games: Mockingjay - Part 1  2014   337.10  331902     6.7
# 3  The Hunger Games: Mockingjay - Part 2  2015   281.67  202380     6.6

# %%
cur.execute("PRAGMA table_info(new_data)")
print(cur.fetchall())
# Out:
# [(0, 'Rank', 'INTEGER', 0, None, 0), (1, 'Title', 'TEXT', 0, None, 0), (2, 'Genre', 'TEXT', 0, None, 0), (3, 'Description', 'TEXT', 0, None, 0), (4, 'Director', 'TEXT', 0, None, 0), (5, 'Actors', 'TEXT', 0, None, 0), (6, 'Year', 'INTEGER', 0, None, 0), (7, 'Runtime (Minutes)', 'INTEGER', 0, None, 0), (8, 'Rating', 'REAL', 0, None, 0), (9, 'Votes', 'INTEGER', 0, None, 0), (10, 'Revenue (Millions)', 'REAL', 0, None, 0), (11, 'Metascore', 'INTEGER', 0, None, 0)]
